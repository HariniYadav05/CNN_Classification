# %%
pip install matplotlib tensorflow
# Out:
# Requirement already satisfied: matplotlib in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (3.10.8)
# Requirement already satisfied: tensorflow in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (2.20.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\harini yadav\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harini yadav\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\harini yadav\appdata\roaming\python\python310\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: setuptools in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (63.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\harini yadav\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: keras>=3.10.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (6.33.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: namex in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: rich in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\harini yadav\appdata\roaming\python\python310\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
x_train = np.loadtxt('input.csv',delimiter=',')
y_train = np.loadtxt('labels.csv',delimiter=',')

x_test = np.loadtxt('input_test.csv',delimiter=',')
y_test = np.loadtxt('labels_test.csv',delimiter=',')

# %%
x_train = x_train.reshape(len(x_train),100, 100, 3)
Y_train = y_train.reshape(len(y_train),1)
x_test = x_test.reshape(len(x_test),100, 100, 3)
y_test = y_test.reshape(len(y_test),1)

x_train = x_train/255.0
x_test = x_test/255.0

datagen= ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

# %%
print("shape of x_train:",x_train.shape)
print("shape of y_train:",x_train.shape)
print("shape of x_test:",x_test.shape)
print("shape of x_test:",x_test.shape)
# Out:
# shape of x_train: (2000, 100, 100, 3)
# shape of y_train: (2000, 100, 100, 3)
# shape of x_test: (400, 100, 100, 3)
# shape of x_test: (400, 100, 100, 3)

# %%
idx = random.randint(0, len(x_train))
plt.imshow(x_train[idx, :])
plt.show()

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    MaxPooling2D((2, 2)),

    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])
# Out:
# c:\Users\Harini yadav\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Input

model = Sequential()

model.add(Input(shape=(100, 100, 3)))

model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\harini yadav\appdata\local\programs\python\python310\lib\site-packages (from scipy) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
model.fit(
    datagen.flow(x_train, y_train, batch_size=32),
    epochs=30,
    validation_data=(x_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 108ms/step - accuracy: 0.5245 - loss: 0.7039 - val_accuracy: 0.5000 - val_loss: 0.6946
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.5090 - loss: 0.6924 - val_accuracy: 0.5450 - val_loss: 0.6846
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5650 - loss: 0.6806 - val_accuracy: 0.5825 - val_loss: 0.6683
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5620 - loss: 0.6748 - val_accuracy: 0.5900 - val_loss: 0.6754
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.5740 - loss: 0.6705 - val_accuracy: 0.6175 - val_loss: 0.6743
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.5805 - loss: 0.6736 - val_accuracy: 0.6500 - val_loss: 0.6498
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.6060 - loss: 0.6580 - val_accuracy: 0.6275 - val_loss: 0.6494
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.6000 - loss: 0.6576 - val_accuracy: 0.5500 - val_loss: 0.6682
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.6220 - loss: 0.6474 - val_accuracy: 0.6050 - val_loss: 0.6428
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.6205 - loss: 0.6541 - val_accuracy: 0.6800 - val_loss: 0.6344
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.6200 - loss: 0.6441 - val_accuracy: 0.6275 - val_loss: 0.6285
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.6405 - loss: 0.6321 - val_accuracy: 0.6800 - val_loss: 0.6084
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.6320 - loss: 0.6453 - val_accuracy: 0.6650 - val_loss: 0.6161
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.6445 - loss: 0.6237 - val_accuracy: 0.6900 - val_loss: 0.5899
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.6575 - loss: 0.6188 - val_accuracy: 0.6675 - val_loss: 0.6024
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.6615 - loss: 0.6127 - val_accuracy: 0.7250 - val_loss: 0.5685
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - accuracy: 0.6705 - loss: 0.6126 - val_accuracy: 0.7125 - val_loss: 0.5700
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - accuracy: 0.6605 - loss: 0.6105 - val_accuracy: 0.7025 - val_loss: 0.5626
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - accuracy: 0.6825 - loss: 0.5952 - val_accuracy: 0.7325 - val_loss: 0.5567
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.6780 - loss: 0.6125 - val_accuracy: 0.6950 - val_loss: 0.5929
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.6860 - loss: 0.6000 - val_accuracy: 0.7200 - val_loss: 0.5512
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - accuracy: 0.6845 - loss: 0.5886 - val_accuracy: 0.7575 - val_loss: 0.5284
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.6925 - loss: 0.5840 - val_accuracy: 0.7525 - val_loss: 0.5237
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - accuracy: 0.6940 - loss: 0.5817 - val_accuracy: 0.7150 - val_loss: 0.5406
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - accuracy: 0.7050 - loss: 0.5704 - val_accuracy: 0.6975 - val_loss: 0.5292
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.6995 - loss: 0.5792 - val_accuracy: 0.7525 - val_loss: 0.5077
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 103ms/step - accuracy: 0.7085 - loss: 0.5680 - val_accuracy: 0.7125 - val_loss: 0.5395
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.7200 - loss: 0.5535 - val_accuracy: 0.7000 - val_loss: 0.5547
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.7155 - loss: 0.5695 - val_accuracy: 0.7250 - val_loss: 0.5341
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 106ms/step - accuracy: 0.7145 - loss: 0.5533 - val_accuracy: 0.7525 - val_loss: 0.5121

# %%
model .evaluate(x_test,y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7525 - loss: 0.5121
# [0.5121482014656067, 0.7524999976158142]

# %%
idx2 = random.randint(0, len(y_test))
plt.imshow(x_test[idx2, :])
plt.show()

y_pred = model.predict(x_test[idx2, :].reshape(1, 100, 100, 3))
y_pred = y_pred > 0.5

if (y_pred == 0):
    pred = 'dog'
else:
    pred = 'cat'

print("Our model says it is a :", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Our model says it is a : cat

# %%
model.save('model.h5')
print('Saved model to model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model to model.h5
